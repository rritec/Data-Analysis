# %% [markdown]
# # Import Data using APIs
# ------------

# %% [markdown]
# 1.	An API is a set of protocols and routines for building and interacting with software applications.
# 2.	API is an acronym and is short for `Application Program Interface`.
# 3.	It is common to pull data from APIs in the `JSON file format`.
# 4.	An API is a bunch of code that allows two software programs to communicate with each other.
#
# [Refer 1: to understand SOAP Vs REST API Theory](https://www.codementor.io/sagaragarwal94/building-a-basic-restful-api-in-python-58k02xsiq)
#
# [Refer 2: to understand SOAP Vs REST API Theory](https://www.guru99.com/comparison-between-web-services.html)

# %% [markdown]
# APIs are everywhere
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ## Working with Movie Database API
# - Open http://www.omdbapi.com
# - Click on api keys
# - Submit the form

# %% [markdown]
# ## <span style="color:red"> Exercise 1: open movie database API </span>

# %%
# Import requests package
import requests
# Assign URL to variable: url
url = 'http://www.omdbapi.com/?apikey=689a5b07&t=saaho'
# Package the request, send the request and catch the response: r
r = requests.get(url)

# %%
type(r)
# Out:
# requests.models.Response

# %%
# Print the text of the response
print(r.text)
# Out:
# {"Title":"Saaho","Year":"2019","Rated":"Not Rated","Released":"30 Aug 2019","Runtime":"170 min","Genre":"Action, Thriller","Director":"Sujeeth","Writer":"Sujeeth (screenplay), Sujeeth (telugu dialogue), K.G.R Ashok (tamil dialogue), Abbas Dalal (hindi dialogue), Hussain Dalal (hindi dialogue)","Actors":"Jacqueline Fernandez, Shraddha Kapoor, Prabhas, Jackie Shroff","Plot":"An undercover cop becomes embroiled in a battle with warring criminals who want to acquire a \"black box,\" their ultimate key to a treasure.","Language":"Telugu, Tamil, Hindi, Malayalam, English, Japanese, Spanish, French, Punjabi","Country":"India","Awards":"N/A","Poster":"https://m.media-amazon.com/images/M/MV5BNDExZjFiYjItMmM3OS00OGUxLTliMTctMzFhZDkzMmFhMzY1XkEyXkFqcGdeQXVyMTA1NTAyMjAw._V1_SX300.jpg","Ratings":[{"Source":"Internet Movie Database","Value":"5.5/10"},{"Source":"Rotten Tomatoes","Value":"9%"}],"Metascore":"N/A","imdbRating":"5.5","imdbVotes":"11,920","imdbID":"tt6836936","Type":"movie","DVD":"N/A",
# ...

# %%
type(r.text)
# Out:
# str

# %%
# Decode the JSON data into a dictionary: json_data
json_data = r.json()

# %%
type(json_data)
# Out:
# dict

# %%
json_data.keys()
# Out:
# dict_keys(['Title', 'Year', 'Rated', 'Released', 'Runtime', 'Genre', 'Director', 'Writer', 'Actors', 'Plot', 'Language', 'Country', 'Awards', 'Poster', 'Ratings', 'Metascore', 'imdbRating', 'imdbVotes', 'imdbID', 'Type', 'DVD', 'BoxOffice', 'Production', 'Website', 'Response'])

# %%
json_data['Title']
# Out:
# 'Saaho'

# %%
# Print each key-value pair in json_data
for k in json_data.keys():
    print(k + ': ', json_data[k])
# Out:
# Title:  Saaho
# Year:  2019
# Rated:  Not Rated
# Released:  30 Aug 2019
# Runtime:  170 min
# Genre:  Action, Thriller
# Director:  Sujeeth
# Writer:  Sujeeth (screenplay), Sujeeth (telugu dialogue), K.G.R Ashok (tamil dialogue), Abbas Dalal (hindi dialogue), Hussain Dalal (hindi dialogue)
# Actors:  Jacqueline Fernandez, Shraddha Kapoor, Prabhas, Jackie Shroff
# Plot:  An undercover cop becomes embroiled in a battle with warring criminals who want to acquire a "black box," their ultimate key to a treasure.
# Language:  Telugu, Tamil, Hindi, Malayalam, English, Japanese, Spanish, French, Punjabi
# Country:  India
# Awards:  N/A
# Poster:  https://m.media-amazon.com/images/M/MV5BNDExZjFiYjItMmM3OS00OGUxLTliMTctMzFhZDkzMmFhMzY1XkEyXkFqcGdeQXVyMTA1NTAyMjAw._V1_SX300.jpg
# Ratings:  [{'Source': 'Internet Movie Database', 'Value': '5.5/10'}, {'Source': 'Rotten Tomatoes', 'Value': '9%'}]
# Metascore:  N/A
# imdbRating:  5.5
# imdbVotes:  11,920
# imdbID:  tt6836936
# Type:  movie
# ...

# %% [markdown]
# > `Home Work`
#
# 1. In 2019 year what are the movies relesed
# 2. Based on movie length get top 5 and display inside the graph

# %% [markdown]
# ## <span style="color:red"> Exercise 2: Wikipedia API </span>

# %%
# Import package
import requests
# Assign URL to variable: url
url = 'https://en.wikipedia.org/w/api.php?action=query&prop=extracts&format=json&exintro=&titles=pizza'
# Package the request, send the request and catch the response: r
r = requests.get(url)
# Decode the JSON data into a dictionary: json_data
json_data = r.json()
# Print the Wikipedia page extract
pizza_extract = json_data['query']['pages']['24768']['extract']
print(pizza_extract)
# Out:
# <p class="mw-empty-elt">
# </p>
#
# <p><b>Pizza</b> (<small>Italian: </small><span title="Representation in the International Phonetic Alphabet (IPA)">[ˈpittsa]</span>, <small>Neapolitan: </small><span title="Representation in the International Phonetic Alphabet (IPA)">[ˈpittsə]</span>) is a savory dish of Italian origin, consisting of a usually round, flattened base of leavened wheat-based dough topped with tomatoes, cheese, and often various other ingredients (anchovies, olives, meat, etc.) baked at a high temperature, traditionally in a wood-fired oven. A small pizza is sometimes called a pizzetta.
# </p><p>In Italy, pizza served in formal settings, such as at a restaurant, is presented unsliced and eaten with the use of a knife and fork. In casual settings it is cut into wedges to be eaten while held in the hand.
# ...

# %%
json_data
# Out:
# {'batchcomplete': '',
#  'warnings': {'extracts': {'*': 'HTML may be malformed and/or unbalanced and may omit inline images. Use at your own risk. Known problems are listed at https://www.mediawiki.org/wiki/Extension:TextExtracts#Caveats.'}},
#  'query': {'normalized': [{'from': 'pizza', 'to': 'Pizza'}],
#   'pages': {'24768': {'pageid': 24768,
#     'ns': 0,
#     'title': 'Pizza',
# ...
